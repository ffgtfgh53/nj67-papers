# %% [markdown]
# # Task 2: Linked List
#
# A linked list is a collection of data elements, whose order is not given by their physical placement in memory. Instead, each element points to the next.
#
# For each of the sub-tasks, add a comment statement at the begining of the code, using the hash symbol '#' to indicate the sub-task the program code belongs to

# %% [markdown]
# ## Task 2.1
# Write the `LinkedList` class in Python. Use of a simple Python list is not sufficient. Include the following methods:
#
# - `insert(data)` inserts the `data` at the begining (head) of the list
# - `delete(data)` attempts to delete `data` from the list; if the item was not present, return `None`
# - `search(data)` returns a Boolean value: `True` if `data` is in the list, `False` if not in the list
# - `count()` should return the number of elements in the list, or zero if empty
# - `to_String()` should return a string for containing a suitably formatted list with the elements seperated by a comma or space, with square brackets at either end, e.g. in the form: `[11, 2, 7, 4]`
# <div style="text-align:right;">[8]</div>
#
# Test `LinkedList` by using the integers in the file `TASK2DATA.TXT`. Use the `to_String()` method to print the resulting contents of the list.
#
# <div style="text-align:right;">[3]</div>

# %%
# Task 2.1# YOUR CODE HERE

# %% [markdown]
# # Task 1.2
# In mathematics, a polynomial in $x$ is an expression $p(x)$ consisting of a single variable $x$ and coefficients, that involve on the operations of addition, subtraction, multiplication and non-negative integer exponentiation of $x$
#
# For example, $x^2 - 4x + 7$, $8x^3 - 5x + 6$, $x^5$, $5$ are polynomials in $x$.
#
#
# More generally, $p(x)$ is a polynomial in $x$ if $$
# p(x) = a_0x^0 + a_1x^1 + a_2x^2 + ... + a_nx^n, $$
#
# where $a_0, ..., a_n$ are the called _coeffecients_ of the term $x^0, ..., x^n$ respectively. The powers of $x$ are called the _exponents_.
#
# We can represent a polynomical in $x$ as a linked list of nodes where each node contains 2 pieces of data, the coefficient and exponent.
#
# Example 1, $x^2-4x+7$ can be represented as:
# ```mermaid
# %% *Note: If you are seeing this in your IDE, please install the "Markdown Preview Mermaid Support" extention. Mermaid support should be built in for JupyterLab>=4.1 and Notebook>=7.1*
# flowchart LR
#     A["[1,2]"] --> B["[-4,1]"]
#     B --> C["[7,0]"]
# ```
#
# Example 2, $x+5$ can be represented as:
# ```mermaid
# %% If you are seeing this, refer to above note
# flowchart LR
#     A["[1,1]"] --> B["[5,0]"]
# ```
#
# Write a Python subclass `Polynomial` using `LinkedList` as its superclass.
#
# The `create` method in the `Polynomial` subclass takes in a list of data items; each data item contains a coefficient and an exponent. The method should ensure that the elements are stored in descending order of the exponent.
#
# the `to_String` method in the `Polynomial` subclass should return a string that represenrs the polynomial in descending power of the exponent. Coefficients of the polynomials should be enclosed withing parenthses characters \(\).
#
# Example, the method `to_String` should return the linked list representation of the polynomicals:
#
# * $x^2+x^3-5$ as "\(1\)\*x\*\*3 + \(1\)\*x\*\*2 + \(-5\)\*x\*\*0"
# * $1-x^4+2x$ as "\(-1\)\*x\*\*4 + \(2\)\*x\*\*1 + \(1\)\*x\*\*0"
#
# <div style="text-align:right;">[6]</div>
#
# Test your program by creating `Polynomial` objects that represent the following polynomials:
#
# * $p(x) = x^2+x^3-5$,
# * $1(x) = 1-x^4+2x$,
#
# Use the `to_String()` method to print the string representation of each of the polynomials.
#
# <div style="text-align:right;">[2]</div>

# %%
# Task 2.2# YOUR CODE HERE

# %% [markdown]
# ## Task 2.3
#
# Let $p(x)$ and $q(x)$ be polynomials such that $$ \begin{align*}
# p(x) &= a_0 + a_1x + a_2x^2 + ... + a_nx^n \\
# q(x) &= b_0 + b_1x + b_2x^2 + ... + b_mx^m
# \end{align*} $$
# where $m$ is not necessarily the same as $n$.
#
# We define the addition of two polynomils $p(x) + q(x)$ to be $$ \\
# p(x) + q(x) = \begin{cases}
# (a_0+b_0)+(a_1+b_1)x+...+(a_m+a_m)x^m+a_{m+1}x^{m+1}+...+a_nx^n &\text{ if } m \le n, \\
# (a_0+b_0)+(a_1+b_1)x+...+(a_n+a_n)x^n+a_{n+1}x^{n+1}+...+a_mx^n &\text{ if } n < m
# \end{cases} $$
# In other words, the resulting polynomial when two polynomials are added is a polynomial where the coefficients are the sum of the coefficients of $p(x)$ and $q(x)$ where the $x$ term has the same exponent.
#
# Amend your code for Task 2.2 to declare the `Polynomial` method `addPoly()` that takes a `Polynomial` and returns another `Polynomial` object which represents the addition of two polynomials.
# <div style="text-align:right;">[7]</div>
#
# Test your `addPoly()` method on the `Polynomial` objects you created in Task 2.2 and use the `to_String()` method to print the string representation of the polynomial.
# <div style="text-align:right;">[1]</div>

# %%
# Task 2.3# YOUR CODE HERE
